# %% [markdown]
# ### Prologue
# Prepare the notebook for inline plotting<br>
# Load require libraries<br>
# Create custom functions<br>
# Load and preprocess data<br>
# Train a random forest using previously optimized/tuned hyper-parameters

# %%
from IPython.display import Image
# %matplotlib inline
# %run rf_analysis_utils.py
# %run nursery_dataprep.py
# Out:
# Utility code in the associated file performs the following steps:
# defines function to print pretty confusion matrix: plot_confusion_matrix()
# defines a function to get the class code by label: get_class_code()
# defines a function to plot a tree inline: tree_to_code()
# defines a function to extract all the structural arrays of a tree: get_tree_structure()
# defines a function to extract a metrics dictionary from a random forest: explore_forest()
# defines a function to pass batches of data to explore_forest(), split by correct/incorrect prediction: batch_analyse_model()
# defines function to plot the mean path lengths from an object returned by explore_forest(): plot_mean_path_lengths()
# defines a function to map the path of an instance down a tree: tree_path()
# defines a function to map the path of an instance down a tree ensemble: forest_path()
# defines a function to find the majority predicted class from object returned by forest_path(): major_class_from_forest_paths()
# defines a function to convert a tree into a function: tree_to_code()
# defines a function to get list of all the paths for one instance out of a forest_paths object: get_paths()
# defines a function to get basic labels back from one hot encoded label names: decode onehot
# defines a function to get basic labels back from one hot encoded label names for all paths in a get_paths() object: decode onehot
# defines a function with an apriori based algorithm for finding frequent patterns from a list of paths: apriori()
# defines a function to sort a frequent pattern list returned by apriori()
# defines a class to accumulate freqent patterns into a rule set rule_accumulator
# defines a function to apply an accumulated rule to a data set: apply_rule()
#
#
# Data Description:
# Nursery Database was derived from a hierarchical decision model
# originally developed to rank applications for nursery schools. It
# was used during several years in 1980's when there was excessive
# enrollment to these schools in Ljubljana, Slovenia, and the
# rejected applications frequently needed an objective
# explanation. The final decision depended on three subproblems:
# occupation of parents and child's nursery, family structure and
# financial standing, and social and health picture of the family.
# The model was developed within expert system shell for decision
# making DEX (M. Bohanec, V. Rajkovic: Expert system for decision
# making. Sistemica 1(1), pp. 145-157, 1990.).
#
# Utility code in the associated file performs the following steps:
# set random seed for the test_train_split
# import packages and modules
# defines a custom summary function: rstr()
# create the list of variable names: var_names
# create the list of features (var_names less class): features
# import the nursery.csv file
# create the pandas dataframe and prints head: nursery
# create the categorical var encoder dictionary: le_dict
# create a function to get any code for a column name and label: get_code
# create the dictionary of categorical values: categories
# create lists and dicts of one hot encoded variable names, onehot_features, onehot_dict
# create the list of class names: class_names
# create the pandas dataframe with encoded vars: nursery_pre
# create the pandas dataframe containing all features less class: X
# create the pandas series containing the class 'decision': y
# create the training and test sets: X_train, y_train, X_test, y_test
# evaluate the training and test set priors and print them: train_priors, test_priors
# create a One Hot Encoder and encode the train set: X_train_enc
# (avoids treating variables as ordinal or continuous)
# pickles objects that are needed by later steps: encoder, X_train_enc, y_train
# creates a closure with the location of the pickle files for easy access to the stored datasets: pickle_path()
#
# nursery.head()
#   parents has_nurs      form children     housing     finance         social  \
# 0   usual   proper  complete        1  convenient  convenient        nonprob
# 1   usual   proper  complete        1  convenient  convenient        nonprob
# 2   usual   proper  complete        1  convenient  convenient  slightly_prob
# 3   usual   proper  complete        1  convenient  convenient  slightly_prob
# 4   usual   proper  complete        1  convenient  convenient    problematic
#
#         health   decision
# 0     priority   priority
# 1    not_recom  not_recom
# 2     priority   priority
# 3    not_recom  not_recom
# 4  recommended   priority
#
# shape
# (12958, 9)
#
# variables summary
# parents                    [[usual, pretentious, great_pret]]
# has_nurs    [[proper, less_proper, improper, critical, ver...
# form              [[complete, completed, incomplete, foster]]
# children                                    [[1, 2, 3, more]]
# housing                   [[convenient, less_conv, critical]]
# finance                                [[convenient, inconv]]
# social                [[nonprob, slightly_prob, problematic]]
# health                   [[priority, not_recom, recommended]]
# decision      [[priority, not_recom, very_recom, spec_prior]]
# dtype: object
#
#
# Training Priors
# not_recom 0.3320837927232635
# priority 0.33042998897464165
# spec_prior 0.31201764057331866
# very_recom 0.025468577728776184
#
#
# Test Priors
# not_recom 0.33641975308641975
# priority 0.3263888888888889
# spec_prior 0.31224279835390945
# very_recom 0.024948559670781894

# %% [markdown]
# The data objects are now saved and given a set of generic names ease of use.

# %%
# get the correct directory for saved objects
pickle_dir_store = open("pickle_dir.pickle", "rb")
pickle_dir = pickle.load(pickle_dir_store)
pickle_dir_store.close()

# helper function for pickling files
def pickle_path(filename):
    return(pickle_dir + '\\' + filename)

# load up the training set (required because of running from script into Jup Note)
encoder_store = open(pickle_path('encoder.pickle'), "rb")
encoder = pickle.load(encoder_store)
encoder_store.close()

X_train_enc_store = open(pickle_path('X_train_enc.pickle'), "rb")
X_train_enc = pickle.load(X_train_enc_store)
X_train_enc_store.close()

y_train_store = open(pickle_path('y_train.pickle'), "rb")
y_train = pickle.load(y_train_store)
y_train_store.close()

# %%
# %run rf_analysis_modelprep.py
# Out:
# Parameter tuning (disabled)
# Utility code in the associated file performs the following steps:
# set random seed for the random forest
# fetch the best parameters from model tuning results
#
# Best OOB Cohen's Kappa during tuning: 0.9881
# Best parameters: {'min_samples_leaf': 1, 'n_estimators': 1000, 'max_depth': 16}
#
# Training a random forest model using best parameters... (please wait)
#
# Done
#
# Created helper function enc_model(). A pipeline: feature encoding -> rf model

# %% [markdown]
# ### Random Forest Performance

# %%
# test the model on unseen data
pred = enc_model.predict(X_test)
print("Cohen's Kappa on unseen instances: " "{:0.4f}".format(metrics.cohen_kappa_score(y_test, pred)))

# view the confusion matrix
cm = metrics.confusion_matrix(y_test, pred)
plot_confusion_matrix(cm, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.figure()
# normalized confusion matrix
plot_confusion_matrix(cm
                      , classes=class_names
                      , normalize=True,
                      title='Normalized confusion matrix')
# Out:
# Cohen's Kappa on unseen instances: 0.9883
# Confusion matrix, without normalization
# [[1308    0    0    0]
#  [   0 1249   20    0]
#  [   0    4 1210    0]
#  [   0    7    0   90]]
# Normalized confusion matrix
# [[1.   0.   0.   0.  ]
#  [0.   0.98 0.02 0.  ]
#  [0.   0.   1.   0.  ]
#  [0.   0.07 0.   0.93]]

# %% [markdown]
# # Analysis of Random Forests by Decision Paths and Votes
# This code uses the sci-kit learn object model to analyse a large tree ensemble trained over the dataset.
#
# Currently only non-weighted trees are supported, so that rules out Boosted models, but a future version is intended to support weighted trees (weighted voting).
#
# Currently only categorical data is supported, so that rules out ExtraTrees, but a future version is intended to support ExtraTrees (random threshold selection).
#
# This method relies on the stochastic process that selects the best split node at each split from a randomly selected restricted subspace.

# %% [markdown]
# # Part 1. Global Explanations
# ## Statistical Analysis of a random forest model using data batches
# * Inductive Properties are based on the training data
# * Transductive Properties are based on the test (held out) data
# * In both cases, the whole dataset is passed into the model and statistics are gathered about how frequently the features are visited.
#
# * OOB data (to do)

# %%
# First instantiate new survey class with the RF model
f_survey = forest_surveyor(model = rf, features = onehot_features, prediction_model = enc_model)

# %%
########################################################################
### This takes a few minutes, so only run when an update is required ###
########################################################################

if True:
    
    batch = X_test
    labels = y_test

    correct_preds = enc_model.predict(batch) == labels
    incorrect_preds = enc_model.predict(batch) != labels
    
    if sum(correct_preds) > 0:
        X = batch[correct_preds.values]
        y = labels[correct_preds.values]
        
        f_survey.fit(encoder.transform(X), y, onehot_features)
        f_cor_stats = f_survey.forest_stats(np.unique(y))
        
    if sum(incorrect_preds) > 0:
        X = batch[incorrect_preds.values]
        y = labels[incorrect_preds.values]
        
        f_survey.fit(encoder.transform(X), y, onehot_features)
        f_incor_stats = f_survey.forest_stats(np.unique(y))
    
    tt_correct_stats_store = open(pickle_path('tt_correct_stats.pickle'), "wb")
    pickle.dump(f_cor_stats, tt_correct_stats_store)
    tt_correct_stats_store.close()
    
    tt_incorrect_stats_store = open(pickle_path('tt_incorrect_stats.pickle'), "wb")
    pickle.dump(f_incor_stats, tt_incorrect_stats_store)
    tt_incorrect_stats_store.close()

tt_correct_stats_store = open(pickle_path('tt_correct_stats.pickle'), "rb")
tt_correct_stats = pickle.load(tt_correct_stats_store)
tt_correct_stats_store.close()

tt_incorrect_stats_store = open(pickle_path('tt_incorrect_stats.pickle'), "rb")
tt_incorrect_stats = pickle.load(tt_incorrect_stats_store)
tt_incorrect_stats_store.close()

# %%
# comparing mean path lengths
plot_mean_path_lengths(tt_correct_stats, class_labels=class_names)

# %%
plot_varimp(rf, onehot_features)

# %%
data = [[tt_correct_stats[k]['p_lower_traversals']] for k in tt_correct_stats.keys() if k != 'all_classes']
plot_feature_stats(data, class_names, 'p_lower_traversals', onehot_features)

# %%
data = [[tt_correct_stats[k]['p_lower_traversals']] for k in tt_correct_stats.keys() if k!= 0 and k != 'all_classes']
plot_feature_stats(data, class_names[1:], 'p_lower_traversals', onehot_features)

# %%
stat_impor_plot(importances = rf.feature_importances_, statistics = tt_correct_stats, label = 'all_classes')

# %%
stat_impor_plot(importances = rf.feature_importances_, statistics = tt_correct_stats, label = 1)

# %%
stat_impor_plot(importances = rf.feature_importances_, statistics = tt_correct_stats, label = 2)

# %%
stat_impor_plot(importances = rf.feature_importances_, statistics = tt_correct_stats, label = 3)

# %% [markdown]
# The test set allows useful comparisons of correctly predicted and incorrectly predicted instances.

# %%
resids, rank = cor_incor_plot(cor = tt_correct_stats, incor = tt_incorrect_stats, label = 1)

# %%
log_ratio = log_ratio_plot(tt_correct_stats[1]['p_lower_traversals']
                           , tt_incorrect_stats[1]['p_lower_traversals']
                           , onehot_features)

# %%
resids, rank = cor_incor_plot(cor = tt_correct_stats, incor = tt_incorrect_stats, label = 2)

# %%
log_ratio = log_ratio_plot(tt_correct_stats[2]['p_lower_traversals']
                           , tt_incorrect_stats[2]['p_lower_traversals']
                           , onehot_features)

# %%
resids, rank = cor_incor_plot(cor = tt_correct_stats, incor = tt_incorrect_stats, label = 3)

# %%
log_ratio = log_ratio_plot(num = tt_correct_stats[3]['m_lower_traversals']
                            , num_err = tt_correct_stats[3]['se_lower_traversals']
                            , denom = tt_incorrect_stats[3]['m_lower_traversals']
                            , denom_err = tt_incorrect_stats[3]['se_lower_traversals']
                            , labels = onehot_features
)

# %% [markdown]
# ### Comparing class profiles

# %%
log_ratio = log_ratio_plot(num = tt_correct_stats[1]['m_lower_traversals'],
                           denom = tt_correct_stats[0]['m_lower_traversals'],
                           num_err = tt_correct_stats[1]['sd_lower_traversals'],
                           denom_err = tt_correct_stats[0]['sd_lower_traversals'],
                           labels = onehot_features)

log_ratio = log_ratio_plot(num = tt_correct_stats[3]['m_lower_traversals'],
                           denom = tt_correct_stats[1]['m_lower_traversals'],
                           num_err = tt_correct_stats[3]['sd_lower_traversals'],
                           denom_err = tt_correct_stats[1]['sd_lower_traversals'],
                           labels = onehot_features)

# %% [markdown]
# ## Open Questions
# There is a strong relationship between feature importance and feature depth, indicating that despite the randomness, feature importance exerts a pressure for a feature to be selected earlier.
#
# Does it also mean a feature will be selected more frequently?
#
# Is the relationship linear, or close to? Does feature depth add new information, compared to feature importance?
# Feature depth is class specific. How can this be exploited?
#
# Is this best suited to multi-class problems?

# %% [markdown]
# # Part 2. Local Explanations
# ## Analysis of decision paths for individual unseen instances in a random forest model
# * Frequent Pattern Mining of decision paths
# * Rule Compression of decision paths

# %%
first_n = 10

batch = X_test[0:first_n]
labels = y_test[0:first_n]

if True:
    '''
    tfp = forest_path(forest = rf
                    , feature_names = onehot_features
                    , instances = batch
                    , labels = labels
                    , feature_encoding = encoder
                    , by_tree = True)

    ifp = forest_path(forest = rf
                    , feature_names = onehot_features
                    , instances = batch
                    , labels = labels
                    , feature_encoding = encoder
                    , by_tree = False)
    '''
nfp = forest_path(forest = rf
                , feature_names = onehot_features
                , instances = batch
                , labels = None
                , feature_encoding = encoder
                , by_tree = False)

# %%
# there is a bug in sklearn causing all the warnings. This should be fixed in next release.
paths = {}
sorted_fp = {}
for instance in range(first_n):
    paths[instance] = get_paths(nfp, instance, by_tree = False, which_trees='majority')
    print('Instance ' + str(instance) + ':    True Class = ' + 
        str(labels.values[instance]) + ' ' + 
          str(get_label(class_col, labels.values[instance])) + 
        '    Majority voting trees = ' + str(len(paths[instance])))

# %%
# there is a bug in sklearn causing all the warnings. This should be fixed in next release.
instance = 5

# Collect useful data for instance
true_class = labels[instance:instance+1].values[0]
pred_probs = enc_model.predict_proba(batch[instance:instance + 1])[0]

# get the class codes produced by the model and the true class
true_class_code = get_label(class_col, true_class)

class_code_confs = np.argsort(pred_probs)[::-1] # descending order
pred_class_code = get_code(class_col, class_names[class_code_confs[0]])
second_class_code = get_code(class_col, class_names[class_code_confs[1]])

print('Test instance id: ' + str(instance))
print('True class: ' + str(true_class))
print('Pedicted Class Probabilities ')
for c, n, p in zip(class_names, range(len(class_names)), pred_probs):
    print(n, c, "{:0.4f}".format(p))

# Display instance row
nurs_id = batch[instance:instance + 1].index[0]
nursery[nurs_id:nurs_id + 1]
# Out:
# Test instance id: 5
# True class: 3
# Pedicted Class Probabilities
# 0 not_recom 0.0020
# 1 priority 0.3841
# 2 spec_prior 0.0029
# 3 very_recom 0.6110
# C:\Dev\Prog\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#      parents  has_nurs      form children    housing     finance   social  \
# 1798   usual  improper  complete        2  less_conv  convenient  nonprob
#
#            health    decision
# 1798  recommended  very_recom

# %%
# training data - could be a representative sample if original tr is too large or unavailable
training_data = X_train
training_labels = y_train

# MAJORITY
# generate a set of paths, sorting can be tuned
sorted_fp = get_sorted_fp(get_paths(nfp, instance, by_tree = False
                                   , which_trees='majority'),
                                 support = 0.2, alpha = 0.0)
# create the rule accumulator
ra = rule_accumulator(vars_dict=vars_dict, onehot_dict = onehot_dict, rule_list=sorted_fp)

# run the profile
ra, model_votes = profile_instance(instance=instance
                                     , fp_object = nfp
                                     , rule_acc = ra
                                     , training_data = encoder.transform(training_data)
                                     , training_labels = training_labels
                                     , features = onehot_features
                                     , class_names = class_names
                                     , stopping_param = 0.8)

# MINORITY
# generate a set of paths, sorting can be tuned
sorted_fp_min = get_sorted_fp(get_paths(nfp, instance, by_tree = False
                                       , which_trees='minority'),
                                 support = 0.2, alpha = 0.0)

# create the rule accumulator
ra_min = rule_accumulator(vars_dict=vars_dict, onehot_dict = onehot_dict, rule_list=sorted_fp_min)

# run the profile
ra_min, model_votes = profile_instance(instance=instance
                                     , fp_object = nfp
                                     , rule_acc = ra_min
                                     , training_data = encoder.transform(training_data)
                                     , training_labels = training_labels
                                     , features = onehot_features
                                     , class_names = class_names
                                     , stopping_param = 0.8)

# %%
pretty_print(ra.rule, onehot_dict)
# Out:
# ['parents_usual True',
#  'social_problematic False',
#  'health_recommended True',
#  'social_problematic False',
#  'children_1 False',
#  'social_problematic False',
#  'has_nurs_improper True',
#  'parents_usual True',
#  'has_nurs_improper True',
#  'housing_critical False',
#  'children_1 False',
#  'has_nurs_critical False',
#  'form_foster False',
#  'has_nurs_very_crit False',
#  'form_complete True',
#  'has_nurs_critical False',
#  'social_problematic False',
#  'children_3 False',
#  'parents_usual True',
#  'has_nurs_very_crit False',
#  'health_not_recom False',
#  'social_problematic False',
#  'has_nurs_very_crit False',
#  'social_nonprob True',
#  'has_nurs_very_crit False',
#  'housing_less_conv True',
#  'health_recommended True',
#  'housing_convenient False',
#  'health_recommended True',
#  'parents_great_pret False',
#  'health_not_recom False',
#  'health_priority False',
#  'children_2 True',
#  'health_not_recom False']

# %%
ra.prune_rule()
pretty_print(ra.pruned_rule, onehot_dict)
# Out:
# ['parents_usual True',
#  'health_recommended True',
#  'has_nurs_improper True',
#  'parents_usual True',
#  'has_nurs_improper True',
#  'form_complete True',
#  'parents_usual True',
#  'social_nonprob True',
#  'housing_less_conv True',
#  'health_recommended True',
#  'health_recommended True',
#  'children_2 True']

# %%
p_count(training_labels.loc[apply_rule(ra.pruned_rule, encoder.transform(training_data), onehot_features)].values)
# Out:
# {'counts': array([1], dtype=int64),
#  'labels': array([3], dtype=int64),
#  'p_counts': array([1.])}

# %%
p_count(training_labels.loc[apply_rule([
 ('parents_usual', False, 0.5),
 ('social_problematic', True, 0.5),
 ('health_recommended', False, 0.5),
 ('form_complete', False, 0.5),
 ('has_nurs_improper', False, 0.5),
 ('housing_critical', True, 0.5),
 ('children_2', False, 0.5)
], encoder.transform(training_data), onehot_features)].values)

# %%
ra.tight_rule

# %%
p_count(training_labels.loc[apply_rule(ra.tight_rule, encoder.transform(training_data), onehot_features)].values)

# %%
ra3 = rule_accumulator(vars_dict=vars_dict, onehot_dict = onehot_dict, rule_list=sorted_fp)
for i in range(3):
    ra3.add_rule()
ra3.prune_rule()
ra3.pruned_rule

# %%
p_count(training_labels.loc[apply_rule(ra3.pruned_rule, encoder.transform(training_data), onehot_features)].values)

# %%
ra_min.rule

# %%
ra_min.prune_rule()
ra_min.pruned_rule

# %%
ra_min.tight_rule

# %%
p_count(training_labels.loc[apply_rule(ra_min.pruned_rule, encoder.transform(training_data), onehot_features)].values)

# %%
p_count(training_labels.loc[apply_rule(ra_min.tight_rule, encoder.transform(training_data), onehot_features)].values)

# %% [markdown]
# # Part 3. Other Demos

# %% [markdown]
# ## treeinterpreter - local explanations from conditional probabilities

# %%
from treeinterpreter import treeinterpreter as ti, utils
prediction, bias, contributions = ti.predict(rf, encoder.transform(batch[instance:instance + 1]))

interp_cols = sum([['predictor'], class_names, ['abseff']], [])
interp = pd.DataFrame(columns=interp_cols)
# now extract contributions for each instance
for c, feature in zip(contributions[0], onehot_features):
    if any(c != 0):
        vals = c.tolist()
        vals.insert(0, feature)
        vals.append(sum(abs(c)))
        interp = interp.append(dict(zip(interp_cols, vals))
                               , ignore_index=True)

# %%
interp = interp.sort_values('abseff', ascending=False).reset_index().drop('index', axis=1)
interp

# %%
interp = interp.sort_values('very_recom', ascending=False).reset_index().drop('index', axis=1)
interp

# %%
priors = dict(zip(interp_cols[1:],  np.append(bias[0], 1.0)))
priors['predictor'] = 'priors (bias)'
totals = dict(zip(interp_cols[1:],  interp.sum()[1:].values))
totals['predictor'] = 'Total'
preds = dict(zip(interp_cols[1:],  np.append(prediction, 1.0)))
preds['predictor'] = 'P(class)'
interp_totals = pd.DataFrame(columns=interp_cols)
interp_totals = interp_totals.append(priors, ignore_index=True)

interp_totals = interp_totals.append(totals, ignore_index=True)
interp_totals = interp_totals.append(preds, ignore_index=True)
interp_totals

# %% [markdown]
# ## LIME

# %%
# basic setup
import lime
import lime.lime_tabular as limtab

np.random.seed(seed)

explainer = limtab.LimeTabularExplainer(training_data=np.array(X_train_enc.todense())
                                        , feature_names=onehot_features
                                        , training_labels=y_train
                                        , class_names=class_names
                                        , categorical_features=range(len(onehot_features))
                                        , categorical_names=onehot_features
                                        , mode='classification'
                                        , discretize_continuous=False
                                        , verbose=False)

exp = explainer.explain_instance(np.array(encoder.transform(batch[instance:instance+1]).todense())[0]
                                 , rf.predict_proba
                                 , top_labels=4)

# %%
fig = exp.as_pyplot_figure(label=pred_class_code)

exp.as_list(label=pred_class_code)

# %%
print(pretty_print(ra3.pruned_rule))
print(pretty_print(ra.pruned_rule))
print('health ' + get_label('health', 2))
print('parents ' + get_label('parents', 2))
print('social ' + get_label('social', 0))
print('finance ' + get_label('finance', 0))
print('housing ' + get_label('housing', 2))
print('form ' + get_label('form', 0))
print('has_nurs ' + get_label('has_nurs', 1))
print('children ' + get_label('children', 1))

# %%
# Show the runner up class details
fig = exp.as_pyplot_figure(label=second_class_code)
exp.as_list(label=second_class_code)

# %%
exp.show_in_notebook()

# %%
# Priors for health feature
health_idx = features.index('health')
print(explainer.categorical_names[health_idx])
print(explainer.feature_frequencies[health_idx])

# %%
# paths = get_paths(nfp, instance, by_tree = False, which_trees='majority')
# Out:
# {(('children_1', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 208,
#  (('children_1', True, 0.5), ('social_problematic', True, 0.5)): 211,
#  (('children_2', False, 0.5), ('has_nurs_very_crit', True, 0.5)): 218,
#  (('children_2', False, 0.5), ('social_problematic', True, 0.5)): 204,
#  (('children_3', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 201,
#  (('children_3', True, 0.5), ('social_problematic', True, 0.5)): 202,
#  (('children_more', True, 0.5), ('has_nurs_critical', True, 0.5)): 204,
#  (('children_more', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 216,
#  (('children_more', True, 0.5), ('social_problematic', True, 0.5)): 205,
#  (('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5)): 267,
#  (('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5)): 234,
#  (('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5)): 214,
#  (('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5)): 232,
#  (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)): 302,
#  (('form_complete', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5)): 207,
#  (('form_complete', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5)): 204,
#  (('form_complete', False, 0.5), ('health_not_recom', True, 0.5)): 241,
#  (('form_complete', False, 0.5), ('housing_convenient', True, 0.5)): 229,
#  (('form_complete', False, 0.5), ('housing_critical', True, 0.5)): 250,
#  (('form_complete', False, 0.5), ('parents_great_pret', True, 0.5)): 222,
#  (('form_complete', False, 0.5), ('parents_usual', False, 0.5)): 288,
#  (('form_complete', False, 0.5), ('social_problematic', True, 0.5)): 280,
#  (('form_foster', True, 0.5),): 249,
#  (('form_incomplete', True, 0.5),): 205,
#  (('has_nurs_critical', True, 0.5), ('has_nurs_less_proper', True, 0.5)): 221,
#  (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 356,
#  (('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5)): 203,
#  (('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_convenient', True, 0.5)): 214,
#  (('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5)): 218,
#  (('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5)): 244,
#  (('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5)): 252,
#  (('has_nurs_critical', True, 0.5), ('health_not_recom', True, 0.5)): 236,
#  (('has_nurs_critical', True, 0.5), ('health_recommended', False, 0.5)): 204,
#  (('has_nurs_critical', True, 0.5), ('housing_convenient', True, 0.5)): 239,
#  (('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)): 247,
#  (('has_nurs_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 222,
#  (('has_nurs_critical', True, 0.5), ('parents_usual', False, 0.5)): 275,
#  (('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)): 287,
#  (('has_nurs_improper', False, 0.5), ('parents_usual', False, 0.5)): 203,
#  (('has_nurs_improper', False, 0.5), ('social_problematic', True, 0.5)): 216,
#  (('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 251,
#  (('has_nurs_less_proper', True, 0.5), ('housing_critical', True, 0.5)): 216,
#  (('has_nurs_less_proper', True, 0.5), ('parents_usual', False, 0.5)): 239,
#  (('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)): 241,
#  (('has_nurs_proper', True, 0.5),): 272,
#  (('has_nurs_very_crit', True, 0.5),): 454,
#  (('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)): 249,
#  (('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)): 235,
#  (('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)): 264,
#  (('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)): 283,
#  (('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5)): 202,
#  (('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)): 244,
#  (('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)): 314,
#  (('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5)): 218,
#  (('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 322,
#  (('health_not_recom', True, 0.5), ('housing_critical', True, 0.5)): 210,
#  (('health_not_recom', True, 0.5), ('parents_usual', False, 0.5)): 240,
#  (('health_not_recom', True, 0.5), ('social_problematic', True, 0.5)): 241,
#  (('health_priority', True, 0.5),): 208,
#  (('health_recommended', False, 0.5), ('housing_critical', True, 0.5)): 202,
#  (('health_recommended', False, 0.5), ('parents_usual', False, 0.5)): 207,
#  (('health_recommended', False, 0.5), ('social_problematic', True, 0.5)): 215,
#  (('housing_convenient', True, 0.5), ('parents_usual', False, 0.5)): 235,
#  (('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 246,
#  (('housing_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 204,
#  (('housing_critical', True, 0.5), ('parents_usual', False, 0.5)): 260,
#  (('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 277,
#  (('housing_less_conv', False, 0.5),): 223,
#  (('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)): 230,
#  (('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 294,
#  (('social_nonprob', False, 0.5),): 222,
#  (('social_problematic', True, 0.5),): 428}

# %%
apriori(transactions = paths, support = 200, max_itemset_size = 5)
# Out:
# No frequent patterns longer than 3 items. Stopping early.
# {(('children_1', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 208,
#  (('children_1', True, 0.5), ('social_problematic', True, 0.5)): 211,
#  (('children_2', False, 0.5), ('has_nurs_very_crit', True, 0.5)): 218,
#  (('children_2', False, 0.5), ('social_problematic', True, 0.5)): 204,
#  (('children_3', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 201,
#  (('children_3', True, 0.5), ('social_problematic', True, 0.5)): 202,
#  (('children_more', True, 0.5), ('has_nurs_critical', True, 0.5)): 204,
#  (('children_more', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 216,
#  (('children_more', True, 0.5), ('social_problematic', True, 0.5)): 205,
#  (('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5)): 234,
#  (('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5)): 214,
#  (('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5)): 232,
#  (('form_complete', False, 0.5), ('health_not_recom', True, 0.5)): 241,
#  (('form_complete', False, 0.5), ('housing_convenient', True, 0.5)): 229,
#  (('form_complete', False, 0.5), ('housing_critical', True, 0.5)): 250,
#  (('form_complete', False, 0.5), ('parents_great_pret', True, 0.5)): 222,
#  (('form_complete', False, 0.5), ('parents_usual', False, 0.5)): 288,
#  (('form_complete', False, 0.5), ('social_problematic', True, 0.5)): 280,
#  (('form_foster', True, 0.5),): 249,
#  (('form_incomplete', True, 0.5),): 205,
#  (('has_nurs_critical', True, 0.5), ('has_nurs_less_proper', True, 0.5)): 221,
#  (('has_nurs_critical', True, 0.5), ('health_not_recom', True, 0.5)): 236,
#  (('has_nurs_critical', True, 0.5), ('health_recommended', False, 0.5)): 204,
#  (('has_nurs_critical', True, 0.5), ('housing_convenient', True, 0.5)): 239,
#  (('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)): 247,
#  (('has_nurs_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 222,
#  (('has_nurs_critical', True, 0.5), ('parents_usual', False, 0.5)): 275,
#  (('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)): 287,
#  (('has_nurs_improper', False, 0.5), ('parents_usual', False, 0.5)): 203,
#  (('has_nurs_improper', False, 0.5), ('social_problematic', True, 0.5)): 216,
#  (('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 251,
#  (('has_nurs_less_proper', True, 0.5), ('housing_critical', True, 0.5)): 216,
#  (('has_nurs_less_proper', True, 0.5), ('parents_usual', False, 0.5)): 239,
#  (('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)): 241,
#  (('has_nurs_proper', True, 0.5),): 272,
#  (('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)): 249,
#  (('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)): 235,
#  (('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)): 264,
#  (('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)): 283,
#  (('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)): 244,
#  (('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)): 314,
#  (('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 322,
#  (('health_not_recom', True, 0.5), ('housing_critical', True, 0.5)): 210,
#  (('health_not_recom', True, 0.5), ('parents_usual', False, 0.5)): 240,
#  (('health_not_recom', True, 0.5), ('social_problematic', True, 0.5)): 241,
#  (('health_priority', True, 0.5),): 208,
#  (('health_recommended', False, 0.5), ('housing_critical', True, 0.5)): 202,
#  (('health_recommended', False, 0.5), ('parents_usual', False, 0.5)): 207,
#  (('health_recommended', False, 0.5), ('social_problematic', True, 0.5)): 215,
#  (('housing_convenient', True, 0.5), ('parents_usual', False, 0.5)): 235,
#  (('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 246,
#  (('housing_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 204,
#  (('housing_critical', True, 0.5), ('parents_usual', False, 0.5)): 260,
#  (('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 277,
#  (('housing_less_conv', False, 0.5),): 223,
#  (('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)): 230,
#  (('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 294,
#  (('social_nonprob', False, 0.5),): 222}

# %%
sorted_fp = get_sorted_fp(paths, 200)
sorted_fp
# Out:
# [((('has_nurs_very_crit', True, 0.5),), 454, 6.118097198041348),
#  ((('social_problematic', True, 0.5),), 428, 6.059123195581797),
#  ((('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   356,
#   5.87493073085203),
#  ((('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)),
#   322,
#   5.7745515455444085),
#  ((('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)),
#   314,
#   5.749392985908253),
#  ((('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   302,
#   5.71042701737487),
#  ((('parents_usual', False, 0.5), ('social_problematic', True, 0.5)),
#   294,
#   5.683579767338681),
#  ((('form_complete', False, 0.5), ('parents_usual', False, 0.5)),
#   288,
#   5.662960480135946),
#  ((('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)),
#   287,
#   5.659482215759621),
#  ((('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)),
#   283,
#   5.645446897643238),
#  ((('form_complete', False, 0.5), ('social_problematic', True, 0.5)),
#   280,
#   5.634789603169249),
#  ((('housing_critical', True, 0.5), ('social_problematic', True, 0.5)),
#   277,
#   5.6240175061873385),
#  ((('has_nurs_critical', True, 0.5), ('parents_usual', False, 0.5)),
#   275,
#   5.616771097666572),
#  ((('has_nurs_proper', True, 0.5),), 272, 5.605802066295998),
#  ((('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5)),
#   267,
#   5.58724865840025),
#  ((('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)),
#   264,
#   5.575949103146316),
#  ((('housing_critical', True, 0.5), ('parents_usual', False, 0.5)),
#   260,
#   5.560681631015528),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   252,
#   5.529429087511423),
#  ((('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   251,
#   5.5254529391317835),
#  ((('form_complete', False, 0.5), ('housing_critical', True, 0.5)),
#   250,
#   5.521460917862246),
#  ((('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)),
#   249,
#   5.517452896464707),
#  ((('form_foster', True, 0.5),), 249, 5.517452896464707),
#  ((('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)),
#   247,
#   5.5093883366279774),
#  ((('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)),
#   246,
#   5.5053315359323625),
#  ((('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)),
#   244,
#   5.497168225293202),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   244,
#   5.497168225293202),
#  ((('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)),
#   241,
#   5.484796933490655),
#  ((('health_not_recom', True, 0.5), ('social_problematic', True, 0.5)),
#   241,
#   5.484796933490655),
#  ((('form_complete', False, 0.5), ('health_not_recom', True, 0.5)),
#   241,
#   5.484796933490655),
#  ((('health_not_recom', True, 0.5), ('parents_usual', False, 0.5)),
#   240,
#   5.480638923341991),
#  ((('has_nurs_less_proper', True, 0.5), ('parents_usual', False, 0.5)),
#   239,
#   5.476463551931511),
#  ((('has_nurs_critical', True, 0.5), ('housing_convenient', True, 0.5)),
#   239,
#   5.476463551931511),
#  ((('has_nurs_critical', True, 0.5), ('health_not_recom', True, 0.5)),
#   236,
#   5.4638318050256105),
#  ((('housing_convenient', True, 0.5), ('parents_usual', False, 0.5)),
#   235,
#   5.459585514144159),
#  ((('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)),
#   235,
#   5.459585514144159),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   234,
#   5.455321115357702),
#  ((('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   232,
#   5.44673737166631),
#  ((('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)),
#   230,
#   5.438079308923196),
#  ((('form_complete', False, 0.5), ('housing_convenient', True, 0.5)),
#   229,
#   5.43372200355424),
#  ((('housing_less_conv', False, 0.5),), 223, 5.407171771460119),
#  ((('social_nonprob', False, 0.5),), 222, 5.402677381872279),
#  ((('form_complete', False, 0.5), ('parents_great_pret', True, 0.5)),
#   222,
#   5.402677381872279),
#  ((('has_nurs_critical', True, 0.5), ('parents_great_pret', True, 0.5)),
#   222,
#   5.402677381872279),
#  ((('has_nurs_critical', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   221,
#   5.3981627015177525),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('children_2', False, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('has_nurs_improper', False, 0.5), ('social_problematic', True, 0.5)),
#   216,
#   5.375278407684165),
#  ((('has_nurs_less_proper', True, 0.5), ('housing_critical', True, 0.5)),
#   216,
#   5.375278407684165),
#  ((('children_more', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   216,
#   5.375278407684165),
#  ((('health_recommended', False, 0.5), ('social_problematic', True, 0.5)),
#   215,
#   5.3706380281276624),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   214,
#   5.365976015021851),
#  ((('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5)),
#   214,
#   5.365976015021851),
#  ((('children_1', True, 0.5), ('social_problematic', True, 0.5)),
#   211,
#   5.351858133476067),
#  ((('health_not_recom', True, 0.5), ('housing_critical', True, 0.5)),
#   210,
#   5.3471075307174685),
#  ((('children_1', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   208,
#   5.337538079701318),
#  ((('health_priority', True, 0.5),), 208, 5.337538079701318),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   207,
#   5.332718793265369),
#  ((('health_recommended', False, 0.5), ('parents_usual', False, 0.5)),
#   207,
#   5.332718793265369),
#  ((('children_more', True, 0.5), ('social_problematic', True, 0.5)),
#   205,
#   5.3230099791384085),
#  ((('form_incomplete', True, 0.5),), 205, 5.3230099791384085),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('has_nurs_critical', True, 0.5), ('health_recommended', False, 0.5)),
#   204,
#   5.318119993844216),
#  ((('children_more', True, 0.5), ('has_nurs_critical', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('housing_critical', True, 0.5), ('parents_great_pret', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('children_2', False, 0.5), ('social_problematic', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   203,
#   5.313205979041787),
#  ((('has_nurs_improper', False, 0.5), ('parents_usual', False, 0.5)),
#   203,
#   5.313205979041787),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   202,
#   5.308267697401205),
#  ((('children_3', True, 0.5), ('social_problematic', True, 0.5)),
#   202,
#   5.308267697401205),
#  ((('health_recommended', False, 0.5), ('housing_critical', True, 0.5)),
#   202,
#   5.308267697401205),
#  ((('children_3', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   201,
#   5.303304908059076)]

# %%
# %run rf_analysis_utils.py
# Out:
# Utility code in the associated file performs the following steps:
# defines function to print pretty confusion matrix: plot_confusion_matrix()
# defines a function to get the class code by label: get_class_code()
# defines a function to plot a tree inline: tree_to_code()
# defines a function to extract all the structural arrays of a tree: get_tree_structure()
# defines a function to extract a metrics dictionary from a random forest: explore_forest()
# defines a function to pass batches of data to explore_forest(), split by correct/incorrect prediction: batch_analyse_model()
# defines function to plot the mean path lengths from an object returned by explore_forest(): plot_mean_path_lengths()
# defines a function to map the path of an instance down a tree: tree_path()
# defines a function to map the path of an instance down a tree ensemble: forest_path()
# defines a function to find the majority predicted class from object returned by forest_path(): major_class_from_forest_paths()
# defines a function to convert a tree into a function: tree_to_code()
# defines a function to get list of all the paths for one instance out of a forest_paths object: get_paths()
# defines a function to get basic labels back from one hot encoded label names: decode onehot
# defines a function to get basic labels back from one hot encoded label names for all paths in a get_paths() object: decode onehot
# defines a function with an apriori based algorithm for finding frequent patterns from a list of paths: apriori()
# defines a function to sort a frequent pattern list returned by apriori()
# defines a class to accumulate freqent patterns into a rule set rule_accumulator
# defines a function to apply an accumulated rule to a data set: apply_rule()

# %%
# create the rule accumulator
ra = rule_accumulator(vars_dict=vars_dict, onehot_dict = onehot_dict, rule_list=sorted_fp)

# run the profile
ra, model_votes = profile_instance(instance=instance
                                     , fp_object = nfp
                                     , rule_acc = ra
                                     , training_data = encoder.transform(training_data)
                                     , training_labels = training_labels
                                     , features = onehot_features
                                     , class_names = class_names
                                     , stopping_param = 0.8)
# Out:
# -----------------------------------------------------------------------
# IndexError                            Traceback (most recent call last)
# <ipython-input-49-d14e806d2cd1> in <module>()
#      10                                      , features = onehot_features
#      11                                      , class_names = class_names
# ---> 12                                      , stopping_param = 0.8)
#
# C:\Dev\Study\python\interpret_basics2\rf_analysis_utils.py in profile_instance(instance, fp_object, rule_acc, training_data, training_labels, features, class_names, stopping_param, target_class)
#    1187     cum_points = 0
#    1188     while current_precision != 1.0 and rule_acc.accumulated_points <= rule_acc.total_points * stopping_param:
# -> 1189         rule_acc.add_rule(p_total = stopping_param)
#    1190         p_counts = p_count(training_labels.loc[apply_rule(rule_acc.rule, training_data, features)].values)
#    1191
#
# C:\Dev\Study\python\interpret_basics2\rf_analysis_utils.py in add_rule(self, p_total)
#     999
#    1000     def add_rule(self, p_total = 0.1):
# -> 1001         next_rule = self.rule_list[self.unapplied_rules[0]]
#    1002         for item in next_rule[0]:
#    1003             if item[0] in self.onehot_dict: # binary feature
#
# IndexError: list index out of range

# %%
# training data - could be a representative sample if original tr is too large or unavailable
training_data = X_train
training_labels = y_train

# MAJORITY
# generate a set of paths, sorting can be tuned
sorted_fp = get_sorted_fp(get_paths(nfp, instance, by_tree = False
                                    , which_trees='majority'),
                                 support = 0.2, alpha = 0.0)
# create the rule accumulator
ra = rule_accumulator(vars_dict=vars_dict, onehot_dict = onehot_dict, rule_list=sorted_fp)

# run the profile
ra, model_votes = profile_instance(instance=instance
                                     , fp_object = nfp
                                     , rule_acc = ra
                                     , training_data = encoder.transform(training_data)
                                     , training_labels = training_labels
                                     , features = onehot_features
                                     , class_names = class_names
                                     , stopping_param = 0.8)

# %%
# training data - could be a representative sample if original tr is too large or unavailable
training_data = X_train
training_labels = y_train

# MAJORITY
# generate a set of paths, sorting can be tuned
sorted_fp = get_sorted_fp(get_paths(nfp, instance, by_tree = False
                                                  , which_trees='majority'),
                                 support = 0.2, alpha = 0.0)
sorted_fp
# Out:
# 120
# {(('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 166, (('health_priority', True, 0.5), ('parents_great_pret', True, 0.5)): 120, (('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)): 185, (('form_foster', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 186, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5), ('housing_critical', True, 0.5)): 121, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 122, (('children_3', True, 0.5), ('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 120, (('children_2', False, 0.5), ('has_nurs_less_proper', True, 0.5)): 151, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)): 163, (('has_nurs_proper', True, 0.5), ('health_recommended', False, 0.5)): 139, (('children_more', True, 0.5), ('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)): 128, (('children_2', False, 0.5), ('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 122, (('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5), ('health_not_recom', True, 0.5)): 130, (('children_3', True, 0.5), ('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 134, (('has_nurs_very_crit', True, 0.5), ('parents_pretentious', True, 0.5)): 127, (('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)): 136, (('has_nurs_improper', False, 0.5), ('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)): 122, (('housing_convenient', True, 0.5), ('housing_critical', True, 0.5), ('parents_usual', False, 0.5)): 138, (('form_complete', False, 0.5), ('health_recommended', False, 0.5), ('parents_usual', False, 0.5)): 136, (('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5), ('housing_critical', True, 0.5)): 132, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('social_nonprob', False, 0.5)): 135, (('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)): 126, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 122, (('has_nurs_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 197, (('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)): 139, (('form_foster', True, 0.5), ('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 147, (('form_foster', True, 0.5), ('social_problematic', True, 0.5)): 186, (('health_not_recom', True, 0.5), ('health_recommended', False, 0.5)): 124, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)): 302, (('health_priority', True, 0.5), ('social_problematic', True, 0.5)): 147, (('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5), ('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 130, (('form_foster', True, 0.5), ('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 130, (('children_1', True, 0.5), ('health_recommended', False, 0.5)): 149, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 252, (('form_incomplete', True, 0.5), ('parents_usual', False, 0.5)): 137, (('children_2', False, 0.5), ('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 130, (('social_slightly_prob', True, 0.5),): 158, (('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)): 314, (('form_foster', True, 0.5), ('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)): 120, (('children_2', False, 0.5), ('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 141, (('has_nurs_less_proper', True, 0.5), ('has_nurs_proper',  ...
# [((('has_nurs_very_crit', True, 0.5),), 454, 6.118097198041348),
#  ((('social_problematic', True, 0.5),), 428, 6.059123195581797),
#  ((('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   356,
#   5.87493073085203),
#  ((('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)),
#   322,
#   5.7745515455444085),
#  ((('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)),
#   314,
#   5.749392985908253),
#  ((('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   302,
#   5.71042701737487),
#  ((('parents_usual', False, 0.5), ('social_problematic', True, 0.5)),
#   294,
#   5.683579767338681),
#  ((('form_complete', False, 0.5), ('parents_usual', False, 0.5)),
#   288,
#   5.662960480135946),
#  ((('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)),
#   287,
#   5.659482215759621),
#  ((('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)),
#   283,
#   5.645446897643238),
#  ((('housing_critical', True, 0.5), ('social_problematic', True, 0.5)),
#   277,
#   5.6240175061873385),
#  ((('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)),
#   264,
#   5.575949103146316),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   252,
#   5.529429087511423),
#  ((('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   251,
#   5.5254529391317835),
#  ((('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)),
#   249,
#   5.517452896464707),
#  ((('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)),
#   246,
#   5.5053315359323625),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   244,
#   5.497168225293202),
#  ((('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)),
#   244,
#   5.497168225293202),
#  ((('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)),
#   241,
#   5.484796933490655),
#  ((('form_complete', False, 0.5), ('health_not_recom', True, 0.5)),
#   241,
#   5.484796933490655),
#  ((('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)),
#   235,
#   5.459585514144159),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   234,
#   5.455321115357702),
#  ((('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)),
#   230,
#   5.438079308923196),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('children_2', False, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   218,
#   5.384495062789089),
#  ((('children_more', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   216,
#   5.375278407684165),
#  ((('has_nurs_improper', False, 0.5), ('social_problematic', True, 0.5)),
#   216,
#   5.375278407684165),
#  ((('health_recommended', False, 0.5), ('social_problematic', True, 0.5)),
#   215,
#   5.3706380281276624),
#  ((('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5)),
#   214,
#   5.365976015021851),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   214,
#   5.365976015021851),
#  ((('children_1', True, 0.5), ('social_problematic', True, 0.5)),
#   211,
#   5.351858133476067),
#  ((('children_1', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   208,
#   5.337538079701318),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   207,
#   5.332718793265369),
#  ((('children_more', True, 0.5), ('social_problematic', True, 0.5)),
#   205,
#   5.3230099791384085),
#  ((('children_2', False, 0.5), ('social_problematic', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   204,
#   5.318119993844216),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   203,
#   5.313205979041787),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   202,
#   5.308267697401205),
#  ((('children_3', True, 0.5), ('social_problematic', True, 0.5)),
#   202,
#   5.308267697401205),
#  ((('children_3', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   201,
#   5.303304908059076),
#  ((('has_nurs_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   197,
#   5.2832037287379885),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   196,
#   5.278114659230517),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   196,
#   5.278114659230517),
#  ((('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   194,
#   5.267858159063328),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   193,
#   5.262690188904886),
#  ((('has_nurs_proper', True, 0.5), ('social_problematic', True, 0.5)),
#   193,
#   5.262690188904886),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   192,
#   5.2574953720277815),
#  ((('form_complete', False, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   192,
#   5.2574953720277815),
#  ((('form_foster', True, 0.5), ('social_problematic', True, 0.5)),
#   186,
#   5.225746673713202),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   186,
#   5.225746673713202),
#  ((('form_foster', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   186,
#   5.225746673713202),
#  ((('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   186,
#   5.225746673713202),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   185,
#   5.220355825078324),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   182,
#   5.204006687076795),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   182,
#   5.204006687076795),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   181,
#   5.198497031265826),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5)),
#   180,
#   5.19295685089021),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   175,
#   5.1647859739235145),
#  ((('form_complete', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   174,
#   5.159055299214529),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   174,
#   5.159055299214529),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   174,
#   5.159055299214529),
#  ((('form_complete', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   174,
#   5.159055299214529),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   174,
#   5.159055299214529),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   173,
#   5.153291594497779),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   172,
#   5.147494476813453),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   172,
#   5.147494476813453),
#  ((('has_nurs_improper', False, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   171,
#   5.14166355650266),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   171,
#   5.14166355650266),
#  ((('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   171,
#   5.14166355650266),
#  ((('has_nurs_very_crit', True, 0.5), ('social_nonprob', False, 0.5)),
#   171,
#   5.14166355650266),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   171,
#   5.14166355650266),
#  ((('children_1', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   169,
#   5.1298987149230735),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   169,
#   5.1298987149230735),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   169,
#   5.1298987149230735),
#  ((('has_nurs_very_crit', True, 0.5), ('housing_less_conv', False, 0.5)),
#   169,
#   5.1298987149230735),
#  ((('children_2', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   169,
#   5.1298987149230735),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   166,
#   5.111987788356544),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   166,
#   5.111987788356544),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   166,
#   5.111987788356544),
#  ((('health_recommended', False, 0.5), ('housing_convenient', True, 0.5)),
#   166,
#   5.111987788356544),
#  ((('form_incomplete', True, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   165,
#   5.10594547390058),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   165,
#   5.10594547390058),
#  ((('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   165,
#   5.10594547390058),
#  ((('form_complete', False, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   164,
#   5.099866427824199),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   163,
#   5.093750200806762),
#  ((('children_3', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   163,
#   5.093750200806762),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   162,
#   5.087596335232384),
#  ((('form_complete', False, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   162,
#   5.087596335232384),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   162,
#   5.087596335232384),
#  ((('health_recommended', False, 0.5), ('parents_great_pret', True, 0.5)),
#   162,
#   5.087596335232384),
#  ((('finance_inconv', True, 0.5),), 162, 5.087596335232384),
#  ((('children_3', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   162,
#   5.087596335232384),
#  ((('housing_less_conv', False, 0.5), ('social_problematic', True, 0.5)),
#   161,
#   5.081404364984463),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   161,
#   5.081404364984463),
#  ((('health_not_recom', True, 0.5), ('health_priority', True, 0.5)),
#   161,
#   5.081404364984463),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   161,
#   5.081404364984463),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   161,
#   5.081404364984463),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   160,
#   5.075173815233827),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   160,
#   5.075173815233827),
#  ((('children_2', False, 0.5), ('health_not_recom', True, 0.5)),
#   159,
#   5.0689042022202315),
#  ((('children_1', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   159,
#   5.0689042022202315),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   159,
#   5.0689042022202315),
#  ((('parents_great_pret', True, 0.5), ('parents_pretentious', True, 0.5)),
#   159,
#   5.0689042022202315),
#  ((('social_slightly_prob', True, 0.5),), 158, 5.062595033026967),
#  ((('children_2', False, 0.5), ('parents_great_pret', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('has_nurs_proper', True, 0.5), ('health_not_recom', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('form_complete', False, 0.5), ('health_priority', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('has_nurs_improper', False, 0.5), ('has_nurs_very_crit', True, 0.5)),
#   158,
#   5.062595033026967),
#  ((('has_nurs_improper', False, 0.5), ('housing_convenient', True, 0.5)),
#   157,
#   5.056245805348308),
#  ((('children_2', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   157,
#   5.056245805348308),
#  ((('has_nurs_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   156,
#   5.049856007249537),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   156,
#   5.049856007249537),
#  ((('form_complete', False, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   156,
#   5.049856007249537),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   156,
#   5.049856007249537),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   155,
#   5.043425116919247),
#  ((('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   155,
#   5.043425116919247),
#  ((('children_2', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   155,
#   5.043425116919247),
#  ((('children_1', True, 0.5), ('housing_convenient', True, 0.5)),
#   155,
#   5.043425116919247),
#  ((('form_complete', False, 0.5), ('housing_less_conv', False, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('form_incomplete', True, 0.5), ('social_problematic', True, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('form_foster', True, 0.5), ('housing_convenient', True, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('housing_less_conv', False, 0.5), ('parents_usual', False, 0.5)),
#   154,
#   5.0369526024136295),
#  ((('has_nurs_very_crit', True, 0.5), ('health_priority', True, 0.5)),
#   153,
#   5.030437921392435),
#  ((('children_1', True, 0.5), ('children_2', False, 0.5)),
#   153,
#   5.030437921392435),
#  ((('children_more', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   153,
#   5.030437921392435),
#  ((('parents_usual', False, 0.5), ('social_nonprob', False, 0.5)),
#   152,
#   5.0238805208462765),
#  ((('children_1', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   152,
#   5.0238805208462765),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   152,
#   5.0238805208462765),
#  ((('children_2', False, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('has_nurs_proper', True, 0.5), ('parents_great_pret', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('housing_critical', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('has_nurs_critical', True, 0.5), ('housing_less_conv', False, 0.5)),
#   151,
#   5.017279836814924),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('children_3', True, 0.5), ('health_not_recom', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('housing_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   151,
#   5.017279836814924),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('children_3', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('form_complete', False, 0.5), ('social_nonprob', False, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_improper', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   150,
#   5.0106352940962555),
#  ((('children_1', True, 0.5), ('health_recommended', False, 0.5)),
#   149,
#   5.003946305945459),
#  ((('children_3', True, 0.5), ('parents_great_pret', True, 0.5)),
#   149,
#   5.003946305945459),
#  ((('has_nurs_proper', True, 0.5), ('housing_convenient', True, 0.5)),
#   149,
#   5.003946305945459),
#  ((('has_nurs_critical', True, 0.5), ('social_nonprob', False, 0.5)),
#   149,
#   5.003946305945459),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   148,
#   4.997212273764115),
#  ((('children_3', True, 0.5), ('health_recommended', False, 0.5)),
#   148,
#   4.997212273764115),
#  ((('children_2', False, 0.5), ('health_recommended', False, 0.5)),
#   148,
#   4.997212273764115),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5)),
#   148,
#   4.997212273764115),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_improper', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   148,
#   4.997212273764115),
#  ((('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   148,
#   4.997212273764115),
#  ((('has_nurs_improper', False, 0.5), ('health_recommended', False, 0.5)),
#   148,
#   4.997212273764115),
#  ((('form_foster', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   148,
#   4.997212273764115),
#  ((('form_foster', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('health_priority', True, 0.5), ('social_problematic', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('children_more', True, 0.5), ('parents_great_pret', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('children_1', True, 0.5), ('parents_great_pret', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   147,
#   4.990432586778736),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   147,
#   4.990432586778736),
#  ((('children_1', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   146,
#   4.983606621708336),
#  ((('has_nurs_improper', False, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   146,
#   4.983606621708336),
#  ((('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   146,
#   4.983606621708336),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   146,
#   4.983606621708336),
#  ((('health_priority', True, 0.5), ('parents_usual', False, 0.5)),
#   145,
#   4.976733742420574),
#  ((('health_recommended', False, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   145,
#   4.976733742420574),
#  ((('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   145,
#   4.976733742420574),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   144,
#   4.969813299576001),
#  ((('form_completed', True, 0.5),), 144, 4.969813299576001),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   144,
#   4.969813299576001),
#  ((('children_more', True, 0.5), ('health_recommended', False, 0.5)),
#   144,
#   4.969813299576001),
#  ((('children_1', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   144,
#   4.969813299576001),
#  ((('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   144,
#   4.969813299576001),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   144,
#   4.969813299576001),
#  ((('children_1', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('health_recommended', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('parents_great_pret', True, 0.5), ('parents_usual', False, 0.5)),
#   143,
#   4.962844630259907),
#  ((('form_incomplete', True, 0.5), ('housing_critical', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('form_foster', True, 0.5), ('form_incomplete', True, 0.5)),
#   143,
#   4.962844630259907),
#  ((('has_nurs_improper', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   142,
#   4.955827057601261),
#  ((('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   141,
#   4.948759890378168),
#  ((('children_2', False, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   141,
#   4.948759890378168),
#  ((('finance_convenient', False, 0.5),), 140, 4.941642422609304),
#  ((('children_3', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   140,
#   4.941642422609304),
#  ((('health_not_recom', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   140,
#   4.941642422609304),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   140,
#   4.941642422609304),
#  ((('children_more', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   140,
#   4.941642422609304),
#  ((('children_1', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   140,
#   4.941642422609304),
#  ((('has_nurs_proper', True, 0.5), ('health_recommended', False, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('children_2', False, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('form_incomplete', True, 0.5), ('has_nurs_critical', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('form_foster', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5)),
#   139,
#   4.9344739331306915),
#  ((('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   138,
#   4.927253685157205),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   138,
#   4.927253685157205),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   138,
#   4.927253685157205),
#  ((('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   138,
#   4.927253685157205),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   138,
#   4.927253685157205),
#  ((('children_1', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   138,
#   4.927253685157205),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   138,
#   4.927253685157205),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   138,
#   4.927253685157205),
#  ((('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   137,
#   4.919980925828125),
#  ((('form_incomplete', True, 0.5), ('parents_usual', False, 0.5)),
#   137,
#   4.919980925828125),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   137,
#   4.919980925828125),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   137,
#   4.919980925828125),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('form_complete', False, 0.5),
#    ('health_recommended', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('form_complete', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('children_1', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_less_proper', True, 0.5), ('social_nonprob', False, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('children_3', True, 0.5), ('has_nurs_improper', False, 0.5)),
#   136,
#   4.912654885736052),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('form_foster', True, 0.5), ('parents_great_pret', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('children_more', True, 0.5), ('has_nurs_improper', False, 0.5)),
#   136,
#   4.912654885736052),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   136,
#   4.912654885736052),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   135,
#   4.90527477843843),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_nonprob', False, 0.5)),
#   135,
#   4.90527477843843),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   135,
#   4.90527477843843),
#  ((('health_recommended', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   135,
#   4.90527477843843),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   135,
#   4.90527477843843),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   135,
#   4.90527477843843),
#  ((('housing_convenient', True, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   135,
#   4.90527477843843),
#  ((('children_2', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   135,
#   4.90527477843843),
#  ((('children_3', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   134,
#   4.897839799950911),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   134,
#   4.897839799950911),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_less_conv', False, 0.5)),
#   134,
#   4.897839799950911),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('housing_convenient', True, 0.5)),
#   134,
#   4.897839799950911),
#  ((('has_nurs_proper', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   134,
#   4.897839799950911),
#  ((('form_foster', True, 0.5), ('health_recommended', False, 0.5)),
#   134,
#   4.897839799950911),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   134,
#   4.897839799950911),
#  ((('children_2', False, 0.5),
#    ('form_complete', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('housing_critical', True, 0.5), ('social_nonprob', False, 0.5)),
#   133,
#   4.890349128221754),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   133,
#   4.890349128221754),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('form_complete', False, 0.5),
#    ('health_recommended', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('form_complete', False, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   133,
#   4.890349128221754),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_improper', False, 0.5),
#    ('housing_critical', True, 0.5)),
#   132,
#   4.882801922586371),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   132,
#   4.882801922586371),
#  ((('form_foster', True, 0.5), ('health_not_recom', True, 0.5)),
#   132,
#   4.882801922586371),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   132,
#   4.882801922586371),
#  ((('children_3', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   132,
#   4.882801922586371),
#  ((('has_nurs_critical', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('housing_critical', True, 0.5)),
#   132,
#   4.882801922586371),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   131,
#   4.875197323201151),
#  ((('children_3', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   131,
#   4.875197323201151),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   131,
#   4.875197323201151),
#  ((('has_nurs_improper', False, 0.5), ('has_nurs_proper', True, 0.5)),
#   131,
#   4.875197323201151),
#  ((('health_priority', True, 0.5), ('housing_critical', True, 0.5)),
#   131,
#   4.875197323201151),
#  ((('children_more', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   131,
#   4.875197323201151),
#  ((('has_nurs_less_proper', True, 0.5), ('housing_less_conv', False, 0.5)),
#   131,
#   4.875197323201151),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_improper', False, 0.5),
#    ('health_not_recom', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('form_foster', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('children_2', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('health_recommended', False, 0.5)),
#   130,
#   4.867534450455582),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('has_nurs_improper', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('children_1', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('children_2', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   130,
#   4.867534450455582),
#  ((('children_2', False, 0.5), ('has_nurs_improper', False, 0.5)),
#   130,
#   4.867534450455582),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('children_3', True, 0.5),
#    ('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   130,
#   4.867534450455582),
#  ((('health_priority', True, 0.5), ('housing_convenient', True, 0.5)),
#   129,
#   4.859812404361672),
#  ((('children_2', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   129,
#   4.859812404361672),
#  ((('form_foster', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   129,
#   4.859812404361672),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('has_nurs_improper', False, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   128,
#   4.852030263919617),
#  ((('form_foster', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('children_1', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('children_3', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('form_incomplete', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('form_complete', False, 0.5),
#    ('health_recommended', False, 0.5),
#    ('housing_critical', True, 0.5)),
#   128,
#   4.852030263919617),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_1', True, 0.5), ('has_nurs_improper', False, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   127,
#   4.844187086458591),
#  ((('has_nurs_improper', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('has_nurs_very_crit', True, 0.5), ('parents_pretentious', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_more', True, 0.5), ('has_nurs_proper', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('children_2', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   127,
#   4.844187086458591),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5)),
#   126,
#   4.836281906951478),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('form_foster', True, 0.5), ('has_nurs_improper', False, 0.5)),
#   126,
#   4.836281906951478),
#  ((('form_foster', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('parents_pretentious', True, 0.5), ('social_problematic', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_improper', False, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   126,
#   4.836281906951478),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   126,
#   4.836281906951478),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_3', True, 0.5),
#    ('children_more', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_1', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_2', False, 0.5),
#    ('form_complete', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_more', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('has_nurs_proper', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('housing_less_conv', False, 0.5), ('parents_great_pret', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('children_3', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   125,
#   4.8283137373023015),
#  ((('health_not_recom', True, 0.5), ('health_recommended', False, 0.5)),
#   124,
#   4.820281565605037),
#  ((('has_nurs_critical', True, 0.5), ('health_priority', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('children_3', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('form_complete', False, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('children_3', True, 0.5), ('form_foster', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('form_incomplete', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   124,
#   4.820281565605037),
#  ((('children_1', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   123,
#   4.812184355372417),
#  ((('children_1', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_not_recom', True, 0.5)),
#   123,
#   4.812184355372417),
#  ((('has_nurs_improper', False, 0.5),
#    ('parents_great_pret', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   123,
#   4.812184355372417),
#  ((('form_complete', False, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('health_priority', True, 0.5)),
#   123,
#   4.812184355372417),
#  ((('children_1', True, 0.5), ('has_nurs_proper', True, 0.5)),
#   123,
#   4.812184355372417),
#  ((('children_2', False, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('has_nurs_improper', False, 0.5),
#    ('has_nurs_less_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('children_3', True, 0.5), ('has_nurs_proper', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('health_not_recom', True, 0.5), ('social_nonprob', False, 0.5)),
#   122,
#   4.804021044733257),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('housing_convenient', True, 0.5), ('social_nonprob', False, 0.5)),
#   122,
#   4.804021044733257),
#  ((('has_nurs_critical', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('children_3', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('form_incomplete', True, 0.5), ('has_nurs_less_proper', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('form_complete', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   122,
#   4.804021044733257),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   121,
#   4.795790545596741),
#  ((('children_3', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   121,
#   4.795790545596741),
#  ((('health_not_recom', True, 0.5), ('housing_less_conv', False, 0.5)),
#   121,
#   4.795790545596741),
#  ((('children_1', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   121,
#   4.795790545596741),
#  ((('children_more', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('housing_critical', True, 0.5)),
#   121,
#   4.795790545596741),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('housing_convenient', True, 0.5)),
#   121,
#   4.795790545596741),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('has_nurs_proper', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   121,
#   4.795790545596741),
#  ((('health_priority', True, 0.5), ('parents_great_pret', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('form_foster', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_1', True, 0.5),
#    ('health_not_recom', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('housing_critical', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_2', False, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('parents_great_pret', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_more', True, 0.5),
#    ('housing_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_1', True, 0.5),
#    ('form_complete', False, 0.5),
#    ('has_nurs_critical', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('has_nurs_less_proper', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_1', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   120,
#   4.787491742782046),
#  ((('finance_inconv', True, 0.5), ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('has_nurs_less_proper', True, 0.5), ('health_priority', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('has_nurs_critical', True, 0.5),
#    ('has_nurs_very_crit', True, 0.5),
#    ('health_recommended', False, 0.5),
#    ('parents_usual', False, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_3', True, 0.5),
#    ('children_more', True, 0.5),
#    ('has_nurs_critical', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_3', True, 0.5),
#    ('housing_convenient', True, 0.5),
#    ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('has_nurs_very_crit', True, 0.5),
#    ('housing_less_conv', False, 0.5),
#    ('social_problematic', True, 0.5)),
#   120,
#   4.787491742782046),
#  ((('children_3', True, 0.5),
#    ('has_nurs_critical', True, 0.5),
#    ('parents_usual', False, 0.5)),
#   120,
#   4.787491742782046)]

# %%
freq_patt = fpg.find_frequent_patterns(get_paths(nfp, instance, by_tree = False
                                                  , which_trees='majority'), 200)
print(freq_patt)

sorted_patt = sort_fp(freq_patt, alpha=0.0)
print(sorted_patt)
# Out:
# {(('has_nurs_less_proper', True, 0.5), ('housing_critical', True, 0.5)): 216, (('form_complete', False, 0.5), ('social_problematic', True, 0.5)): 280, (('form_complete', False, 0.5), ('has_nurs_improper', False, 0.5)): 214, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)): 207, (('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 322, (('health_priority', True, 0.5),): 208, (('health_recommended', False, 0.5), ('social_problematic', True, 0.5)): 215, (('form_complete', False, 0.5), ('health_not_recom', True, 0.5)): 241, (('social_nonprob', False, 0.5),): 222, (('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 202, (('children_2', False, 0.5), ('social_problematic', True, 0.5)): 204, (('children_3', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 201, (('health_not_recom', True, 0.5), ('social_problematic', True, 0.5)): 241, (('has_nurs_improper', False, 0.5), ('parents_usual', False, 0.5)): 203, (('housing_critical', True, 0.5), ('social_problematic', True, 0.5)): 277, (('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)): 287, (('has_nurs_less_proper', True, 0.5), ('parents_usual', False, 0.5)): 239, (('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)): 241, (('has_nurs_critical', True, 0.5), ('health_recommended', False, 0.5)): 204, (('health_not_recom', True, 0.5), ('housing_critical', True, 0.5)): 210, (('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)): 244, (('social_problematic', True, 0.5),): 428, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)): 214, (('children_more', True, 0.5), ('social_problematic', True, 0.5)): 205, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)): 218, (('has_nurs_proper', True, 0.5),): 272, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)): 203, (('health_recommended', False, 0.5), ('parents_usual', False, 0.5)): 207, (('housing_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 204, (('children_more', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 216, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 204, (('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)): 302, (('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5)): 267, (('housing_critical', True, 0.5), ('parents_usual', False, 0.5)): 260, (('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)): 247, (('form_complete', False, 0.5), ('housing_convenient', True, 0.5)): 229, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 356, (('children_3', True, 0.5), ('social_problematic', True, 0.5)): 202, (('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)): 235, (('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)): 234, (('has_nurs_critical', True, 0.5), ('parents_great_pret', True, 0.5)): 222, (('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)): 252, (('children_more', True, 0.5), ('has_nurs_critical', True, 0.5)): 204, (('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5)): 232, (('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)): 246, (('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)): 314, (('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5), ('social_problematic', True, 0.5)): 218, (('has_nurs_critical', True, 0.5), ('parents_usual', False, 0.5)): 275, (('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)): 230, (('form_complete', False, 0.5), ('housing_critical', True, 0.5)): 250, (('has_nurs_improper', False, 0.5), ('social_problematic', True, 0.5)): 216, (('form_complete', False, 0.5), ('parents_g ...
# [((('has_nurs_very_crit', True, 0.5),), 454, 6.118097198041348), ((('social_problematic', True, 0.5),), 428, 6.059123195581797), ((('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)), 356, 5.87493073085203), ((('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)), 322, 5.7745515455444085), ((('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)), 314, 5.749392985908253), ((('form_complete', False, 0.5), ('has_nurs_very_crit', True, 0.5)), 302, 5.71042701737487), ((('parents_usual', False, 0.5), ('social_problematic', True, 0.5)), 294, 5.683579767338681), ((('form_complete', False, 0.5), ('parents_usual', False, 0.5)), 288, 5.662960480135946), ((('has_nurs_critical', True, 0.5), ('social_problematic', True, 0.5)), 287, 5.659482215759621), ((('has_nurs_very_crit', True, 0.5), ('housing_critical', True, 0.5)), 283, 5.645446897643238), ((('form_complete', False, 0.5), ('social_problematic', True, 0.5)), 280, 5.634789603169249), ((('housing_critical', True, 0.5), ('social_problematic', True, 0.5)), 277, 5.6240175061873385), ((('has_nurs_critical', True, 0.5), ('parents_usual', False, 0.5)), 275, 5.616771097666572), ((('has_nurs_proper', True, 0.5),), 272, 5.605802066295998), ((('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5)), 267, 5.58724865840025), ((('has_nurs_very_crit', True, 0.5), ('housing_convenient', True, 0.5)), 264, 5.575949103146316), ((('housing_critical', True, 0.5), ('parents_usual', False, 0.5)), 260, 5.560681631015528), ((('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('social_problematic', True, 0.5)), 252, 5.529429087511423), ((('has_nurs_less_proper', True, 0.5), ('has_nurs_very_crit', True, 0.5)), 251, 5.5254529391317835), ((('form_complete', False, 0.5), ('housing_critical', True, 0.5)), 250, 5.521460917862246), ((('has_nurs_very_crit', True, 0.5), ('health_not_recom', True, 0.5)), 249, 5.517452896464707), ((('form_foster', True, 0.5),), 249, 5.517452896464707), ((('has_nurs_critical', True, 0.5), ('housing_critical', True, 0.5)), 247, 5.5093883366279774), ((('housing_convenient', True, 0.5), ('social_problematic', True, 0.5)), 246, 5.5053315359323625), ((('has_nurs_very_crit', True, 0.5), ('parents_great_pret', True, 0.5)), 244, 5.497168225293202), ((('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5), ('parents_usual', False, 0.5)), 244, 5.497168225293202), ((('has_nurs_less_proper', True, 0.5), ('social_problematic', True, 0.5)), 241, 5.484796933490655), ((('health_not_recom', True, 0.5), ('social_problematic', True, 0.5)), 241, 5.484796933490655), ((('form_complete', False, 0.5), ('health_not_recom', True, 0.5)), 241, 5.484796933490655), ((('health_not_recom', True, 0.5), ('parents_usual', False, 0.5)), 240, 5.480638923341991), ((('has_nurs_less_proper', True, 0.5), ('parents_usual', False, 0.5)), 239, 5.476463551931511), ((('has_nurs_critical', True, 0.5), ('housing_convenient', True, 0.5)), 239, 5.476463551931511), ((('has_nurs_critical', True, 0.5), ('health_not_recom', True, 0.5)), 236, 5.4638318050256105), ((('housing_convenient', True, 0.5), ('parents_usual', False, 0.5)), 235, 5.459585514144159), ((('has_nurs_very_crit', True, 0.5), ('health_recommended', False, 0.5)), 235, 5.459585514144159), ((('form_complete', False, 0.5), ('has_nurs_critical', True, 0.5), ('has_nurs_very_crit', True, 0.5)), 234, 5.455321115357702), ((('form_complete', False, 0.5), ('has_nurs_less_proper', True, 0.5)), 232, 5.44673737166631), ((('parents_great_pret', True, 0.5), ('social_problematic', True, 0.5)), 230, 5.438079308923196), ((('form_complete', False, 0.5), ('housing_convenient', True, 0.5)), 229, 5.43372200355424), ((('housing_less_conv', False, 0.5),), 223, 5.407171771460119), ((('social_nonprob', False, 0.5),), 222, 5.402677381872279), ((('form_complete', False, 0.5), ('parents_great_pret', True, 0.5)), 222, 5.402677381872279), ((('has_nurs_critical', True, 0.5), ('parents_great_pret', True, 0.5)), 222, 5.402677381872 ...

# %%
get_paths(nfp, instance, by_tree = False
                                                  , which_trees='majority')
# Out:
# [[('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_3', True, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_3', True, 0.5),
#   ('social_problematic', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_1', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_problematic', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_2', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('finance_convenient', False, 0.5)],
#  [('housing_convenient', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_3', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_3', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_3', True, 0.5),
#   ('finance_inconv', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_2', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_more', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_2', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_1', True, 0.5),
#   ('children_2', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_1', True, 0.5),
#   ('form_completed', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_3', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_1', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('parents_great_pret', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_2', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5)],
#  [('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_more', True, 0.5),
#   ('children_2', False, 0.5),
#   ('social_problematic', True, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_foster', True, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_2', False, 0.5)],
#  [('children_1', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_2', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('children_1', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('children_3', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_problematic', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('form_completed', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('finance_convenient', False, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_more', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_3', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_1', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_inconv', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('children_1', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_2', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_3', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_1', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_more', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_3', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_1', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_inconv', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_slightly_prob', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_3', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_2', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('finance_inconv', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('children_2', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_improper', False, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_3', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_2', False, 0.5),
#   ('finance_inconv', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_more', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_2', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_more', True, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_3', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_3', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_3', True, 0.5),
#   ('children_more', True, 0.5),
#   ('children_1', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('children_1', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_proper', True, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('health_recommended', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_2', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('has_nurs_improper', False, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_3', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_more', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_3', True, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_more', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_improper', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_3', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
# ...
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_2', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_critical', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('finance_convenient', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_completed', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_3', True, 0.5)],
#  [('social_problematic', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_1', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_3', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('has_nurs_improper', False, 0.5)],
#  [('housing_convenient', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_3', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('health_priority', False, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_3', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('children_more', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_1', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('children_2', False, 0.5),
#   ('social_problematic', True, 0.5)],
#  [('social_slightly_prob', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_2', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('children_more', True, 0.5)],
#  [('has_nurs_less_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_1', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('children_more', True, 0.5)],
#  [('housing_convenient', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_1', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_2', False, 0.5)],
#  [('health_priority', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('form_completed', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_1', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('parents_usual', False, 0.5)],
#  [('parents_great_pret', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('children_1', True, 0.5),
#   ('children_more', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('children_2', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('has_nurs_critical', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_2', False, 0.5)],
#  [('housing_convenient', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_1', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('form_incomplete', True, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('children_more', True, 0.5),
#   ('children_3', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('form_complete', False, 0.5)],
#  [('health_recommended', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_more', True, 0.5)],
#  [('health_not_recom', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('children_3', True, 0.5),
#   ('children_1', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('parents_pretentious', True, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('children_3', True, 0.5),
#   ('form_foster', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_slightly_prob', True, 0.5),
#   ('housing_critical', True, 0.5)],
#  [('children_1', True, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('children_3', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_more', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('housing_critical', True, 0.5),
#   ('form_foster', True, 0.5)],
#  [('parents_usual', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_nonprob', False, 0.5),
#   ('housing_critical', True, 0.5),
#   ('finance_inconv', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_proper', True, 0.5),
#   ('has_nurs_improper', False, 0.5)],
#  [('housing_critical', False, 0.5),
#   ('health_priority', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('children_more', True, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_proper', True, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('health_priority', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('has_nurs_very_crit', True, 0.5),
#   ('health_not_recom', True, 0.5),
#   ('children_more', True, 0.5),
#   ('social_problematic', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('housing_less_conv', False, 0.5),
#   ('children_3', True, 0.5),
#   ('children_2', False, 0.5),
#   ('form_incomplete', True, 0.5),
#   ('social_nonprob', False, 0.5)],
#  [('has_nurs_very_crit', True, 0.5),
#   ('has_nurs_critical', True, 0.5),
#   ('has_nurs_less_proper', True, 0.5),
#   ('health_recommended', False, 0.5),
#   ('housing_convenient', True, 0.5),
#   ('parents_usual', False, 0.5),
#   ('form_complete', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('finance_convenient', False, 0.5),
#   ('children_2', False, 0.5),
#   ('housing_less_conv', False, 0.5)],
#  [('has_nurs_proper', False, 0.5),
#   ('health_recommended', False, 0.5),
#   ('social_problematic', True, 0.5),
#   ('children_1', True, 0.5),
#   ('parents_great_pret', True, 0.5),
#   ('children_2', False, 0.5),
#   ('has_nurs_improper', False, 0.5),
#   ('parents_pretentious', True, 0.5),
#   ('form_complete', False, 0.5),
#   ('housing_critical', True, 0.5)]]
